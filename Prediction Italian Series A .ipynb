# %%
import pandas as pd

# %%
matches = pd.read_csv("NewItalian Series A.csv", index_col=0)

# %%
df3 = pd.DataFrame(matches)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2019-08-24  18:00  Serie A  Matchweek 1  Sat  Away      W  1.0  0.0
# 1  2019-08-31  20:45  Serie A  Matchweek 2  Sat  Home      W  4.0  3.0
# 2  2019-09-14  15:00  Serie A  Matchweek 3  Sat  Away      D  0.0  0.0
# 4  2019-09-21  18:00  Serie A  Matchweek 4  Sat  Home      W  2.0  1.0
# 5  2019-09-24  21:00  Serie A  Matchweek 5  Tue  Away      W  2.0  1.0
#
#         opponent  ...              referee  match report  notes    sh  sot  \
# 0          Parma  ...        Fabio Maresca  Match Report    NaN  14.0  4.0
# 1         Napoli  ...       Daniele Orsato  Match Report    NaN  12.0  7.0
# 2     Fiorentina  ...  Massimiliano Irrati  Match Report    NaN   8.0  4.0
# 4  Hellas Verona  ...    Federico La Penna  Match Report    NaN  19.0  1.0
# 5        Brescia  ...      Fabrizio Pasqua  Match Report    NaN  19.0  5.0
#
#    dist   pk pkatt season      team
# 0  17.1  0.0   0.0   2022  Juventus
# 1  18.0  0.0   0.0   2022  Juventus
# 2  24.8  0.0   0.0   2022  Juventus
# 4  20.8  1.0   1.0   2022  Juventus
# 5  16.5  0.0   0.0   2022  Juventus
#
# [5 rows x 26 columns]

# %%
matches.shape
# Out:
# (11400, 26)

# %%
matches["team"].value_counts()
# Out:
# Roma              570
# Lazio             570
# Internazionale    570
# Milan             570
# Udinese           570
# Fiorentina        570
# Cagliari          532
# Juventus          532
# Sampdoria         532
# Chievo            494
# Genoa             494
# Atalanta          494
# Napoli            494
# Parma             418
# Palermo           418
# Torino            418
# Bologna           418
# Catania           304
# Sassuolo          266
# Siena             266
# Empoli            266
# Hellas Verona     190
# Livorno           190
# Lecce             190
# Reggina           152
# SPAL              114
# Cesena            114
# Pescara            76
# Frosinone          76
# Messina            76
# Ascoli             76
# Bari               76
# Brescia            76
# Crotone            76
# Treviso            38
# Benevento          38
# Novara             38
# Carpi              38
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 22    300
# Matchweek 35    300
# Matchweek 26    300
# Matchweek 16    300
# Matchweek 21    300
# Matchweek 20    300
# Matchweek 36    300
# Matchweek 25    300
# Matchweek 13    300
# Matchweek 28    300
# Matchweek 4     300
# Matchweek 2     300
# Matchweek 30    300
# Matchweek 33    300
# Matchweek 37    300
# Matchweek 15    300
# Matchweek 38    300
# Matchweek 8     300
# Matchweek 32    300
# Matchweek 29    300
# Matchweek 7     300
# Matchweek 3     300
# Matchweek 18    300
# Matchweek 9     300
# Matchweek 17    300
# Matchweek 23    300
# Matchweek 24    300
# Matchweek 31    300
# Matchweek 5     300
# Matchweek 27    300
# Matchweek 1     300
# Matchweek 34    300
# Matchweek 14    300
# Matchweek 12    300
# Matchweek 19    300
# Matchweek 11    300
# Matchweek 10    300
# Matchweek 6     300
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes            object
# sh              float64
# sot             float64
# dist            float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga       opponent  \
# 0  2019-08-24  18:00   Matchweek 1  Sat  Away      W  1.0  0.0          Parma
# 1  2019-08-31  20:45   Matchweek 2  Sat  Home      W  4.0  3.0         Napoli
# 2  2019-09-14  15:00   Matchweek 3  Sat  Away      D  0.0  0.0     Fiorentina
# 4  2019-09-21  18:00   Matchweek 4  Sat  Home      W  2.0  1.0  Hellas Verona
# 5  2019-09-24  21:00   Matchweek 5  Tue  Away      W  2.0  1.0        Brescia
# ..        ...    ...           ...  ...   ...    ...  ...  ...            ...
# 43 2006-04-15    NaN  Matchweek 34  Sat  Away      D  1.0  1.0       Cagliari
# 44 2006-04-22    NaN  Matchweek 35  Sat  Home      D  1.0  1.0          Lazio
# 45 2006-04-30    NaN  Matchweek 36  Sun  Away      W  3.0  0.0          Siena
# 46 2006-05-07    NaN  Matchweek 37  Sun  Home      W  2.0  1.0        Palermo
# 47 2006-05-14    NaN  Matchweek 38  Sun  Away      W  2.0  0.0        Reggina
#
#      xg  ...              referee  match report    sh  sot  dist   pk pkatt  \
# 0   1.3  ...        Fabio Maresca  Match Report  14.0  4.0  17.1  0.0   0.0
# 1   1.4  ...       Daniele Orsato  Match Report  12.0  7.0  18.0  0.0   0.0
# 2   0.3  ...  Massimiliano Irrati  Match Report   8.0  4.0  24.8  0.0   0.0
# 4   2.0  ...    Federico La Penna  Match Report  19.0  1.0  20.8  1.0   1.0
# 5   1.7  ...      Fabrizio Pasqua  Match Report  19.0  5.0  16.5  0.0   0.0
# ..  ...  ...                  ...           ...   ...  ...   ...  ...   ...
# 43  NaN  ...       Nicola Ayroldi  Match Report   NaN  NaN   NaN  0.0   NaN
# 44  NaN  ...   Gianluca Paparesta  Match Report   NaN  NaN   NaN  0.0   NaN
# 45  NaN  ...    Daniele Tombolini  Match Report   NaN  NaN   NaN  0.0   NaN
# 46  NaN  ...    Massimo De Santis  Match Report   NaN  NaN   NaN  0.0   NaN
# 47  NaN  ...           Luca Banti  Match Report   NaN  NaN   NaN  0.0   NaN
#
#     season      team  target
# 0     2022  Juventus       1
# 1     2022  Juventus       1
# 2     2022  Juventus       0
# 4     2022  Juventus       1
# 5     2022  Juventus       1
# ..     ...       ...     ...
# 43    2008  Juventus       0
# 44    2008  Juventus       0
# 45    2008  Juventus       1
# 46    2008  Juventus       1
# 47    2008  Juventus       1
#
# [11400 rows x 25 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga       opponent  \
# 0  2019-08-24  18:00   Matchweek 1  Sat  Away      W  1.0  0.0          Parma
# 1  2019-08-31  20:45   Matchweek 2  Sat  Home      W  4.0  3.0         Napoli
# 2  2019-09-14  15:00   Matchweek 3  Sat  Away      D  0.0  0.0     Fiorentina
# 4  2019-09-21  18:00   Matchweek 4  Sat  Home      W  2.0  1.0  Hellas Verona
# 5  2019-09-24  21:00   Matchweek 5  Tue  Away      W  2.0  1.0        Brescia
# ..        ...    ...           ...  ...   ...    ...  ...  ...            ...
# 43 2006-04-15    NaN  Matchweek 34  Sat  Away      D  1.0  1.0       Cagliari
# 44 2006-04-22    NaN  Matchweek 35  Sat  Home      D  1.0  1.0          Lazio
# 45 2006-04-30    NaN  Matchweek 36  Sun  Away      W  3.0  0.0          Siena
# 46 2006-05-07    NaN  Matchweek 37  Sun  Home      W  2.0  1.0        Palermo
# 47 2006-05-14    NaN  Matchweek 38  Sun  Away      W  2.0  0.0        Reggina
#
#      xg  ...  sot  dist   pk pkatt season      team target  venue_code  \
# 0   1.3  ...  4.0  17.1  0.0   0.0   2022  Juventus      1           0
# 1   1.4  ...  7.0  18.0  0.0   0.0   2022  Juventus      1           1
# 2   0.3  ...  4.0  24.8  0.0   0.0   2022  Juventus      0           0
# 4   2.0  ...  1.0  20.8  1.0   1.0   2022  Juventus      1           1
# 5   1.7  ...  5.0  16.5  0.0   0.0   2022  Juventus      1           0
# ..  ...  ...  ...   ...  ...   ...    ...       ...    ...         ...
# 43  NaN  ...  NaN   NaN  0.0   NaN   2008  Juventus      0           0
# 44  NaN  ...  NaN   NaN  0.0   NaN   2008  Juventus      0           1
# 45  NaN  ...  NaN   NaN  0.0   NaN   2008  Juventus      1           0
# 46  NaN  ...  NaN   NaN  0.0   NaN   2008  Juventus      1           1
# 47  NaN  ...  NaN   NaN  0.0   NaN   2008  Juventus      1           0
#
#     opp_code  day_code
# 0         27         5
# 1         24         5
# 2         13         5
# 4         16         5
# 5          5         1
# ..       ...       ...
# 43         6         5
# 44        19         5
# 45        34         6
# 46        26         6
# 47        29         6
#
# [11400 rows x 28 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
svm = svm.SVC(kernel='linear')

# %%
nb = GaussianNB()

# %%
gb = GradientBoostingClassifier(learning_rate=0.05,max_depth=3,max_features=0.5,random_state=0)

# %%
train = matches[matches["date"] < '2018-01-01']

# %%
test = matches[matches["date"] > '2018-01-01']

# %%
predictors = ["venue_code", "opp_code", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
svm.fit(train[predictors], train["target"])
# Out:
# SVC(kernel='linear')

# %%
nb.fit(train[predictors], train["target"])
# Out:
# GaussianNB()

# %%
gb.fit(train[predictors], train["target"])
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_features=0.5, random_state=0)

# %%
predrf = rf.predict(test[predictors])
predsvm= svm.predict(test[predictors])
prednb= nb.predict(test[predictors])
predgb=gb.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
RFacc = accuracy_score(test["target"], predrf)
SVMacc = accuracy_score(test["target"], predsvm)
NBacc = accuracy_score(test["target"], prednb)
GBacc = accuracy_score(test["target"], predgb)

# %%
combinedrf = pd.DataFrame(dict(actual=test["target"], predicted=predrf))
combinedsvm = pd.DataFrame(dict(actual=test["target"], predicted=predsvm))
combinednb = pd.DataFrame(dict(actual=test["target"], predicted=prednb))
combinedgb= pd.DataFrame(dict(actual=test["target"], predicted=predgb))

# %%
pd.crosstab(index=combinedrf["actual"], columns=combinedrf["predicted"])
# Out:
# predicted    0    1
# actual
# 0          975  213
# 1          488  228

# %%
pd.crosstab(index=combinedsvm["actual"], columns=combinedsvm["predicted"])
# Out:
# predicted     0
# actual
# 0          1188
# 1           716

# %%
pd.crosstab(index=combinednb["actual"], columns=combinednb["predicted"])
# Out:
# predicted     0   1
# actual
# 0          1104  84
# 1           649  67

# %%
pd.crosstab(index=combinedgb["actual"], columns=combinedgb["predicted"])
# Out:
# predicted     0    1
# actual
# 0          1070  118
# 1           571  145

# %%
from sklearn.metrics import precision_score

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Roma").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(5, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga    opponent  \
# 7  2017-10-01  18:00   Matchweek 7  Sun  Away      W  2.0  0.0       Milan
# 8  2017-10-14  20:45   Matchweek 8  Sat  Home      L  0.0  1.0      Napoli
# 10 2017-10-22  15:00   Matchweek 9  Sun  Away      W  1.0  0.0      Torino
# 11 2017-10-25  20:45  Matchweek 10  Wed  Home      W  1.0  0.0     Crotone
# 12 2017-10-28  20:45  Matchweek 11  Sat  Home      W  1.0  0.0     Bologna
# ..        ...    ...           ...  ...   ...    ...  ...  ...         ...
# 43 2020-07-19  21:45  Matchweek 34  Sun  Home      D  2.0  2.0       Inter
# 44 2020-07-22  21:45  Matchweek 35  Wed  Away      W  6.0  1.0        SPAL
# 45 2020-07-26  19:30  Matchweek 36  Sun  Home      W  2.0  1.0  Fiorentina
# 46 2020-07-29  21:45  Matchweek 37  Wed  Away      W  3.0  2.0      Torino
# 47 2020-08-01  20:45  Matchweek 38  Sat  Away      W  3.0  1.0    Juventus
#
#      xg  ...  venue_code  opp_code  day_code gf_rolling ga_rolling sh_rolling  \
# 7   1.4  ...           0        23         6        2.4        0.8       19.2
# 8   0.4  ...           1        24         5        2.6        0.8       20.4
# 10  1.2  ...           0        35         6        2.4        0.4       18.6
# 11  2.7  ...           1        11         2        2.0        0.4       15.2
# 12  1.5  ...           1         4         5        1.4        0.4       15.4
# ..  ...  ...         ...       ...       ...        ...        ...        ...
# 43  1.4  ...           1        17         6        1.6        1.2       18.0
# 44  1.8  ...           0        31         2        2.0        1.2       16.0
# 45  2.8  ...           1        13         6        3.0        1.0       17.8
# 46  2.6  ...           0        35         2        3.0        1.0       16.8
# 47  1.9  ...           0        18         5        3.0        1.4       16.0
#
#    sot_rolling  dist_rolling  pk_rolling  pkatt_rolling
# 7          5.4         18.86         0.0            0.2
# 8          6.4         18.66         0.0            0.2
# 10         6.4         18.18         0.0            0.2
# 11         5.4         18.68         0.0            0.2
# 12         4.8         17.82         0.2            0.4
# ..         ...           ...         ...            ...
# 43         5.0         18.14         0.2            0.2
# 44         4.8         16.20         0.2            0.2
# 45         6.0         16.10         0.2            0.2
# 46         5.0         16.40         0.6            0.6
# 47         4.8         16.94         0.8            0.8
#
# [109 rows x 35 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                   date   time         round  day venue result   gf   ga  \
# team
# Atalanta 6  2017-09-24  20:45   Matchweek 6  Sun  Away      D  1.0  1.0
#          8  2017-10-01  20:45   Matchweek 7  Sun  Home      D  2.0  2.0
#          9  2017-10-15  15:00   Matchweek 8  Sun  Away      L  1.0  3.0
#          11 2017-10-22  15:00   Matchweek 9  Sun  Home      W  1.0  0.0
#          12 2017-10-25  18:30  Matchweek 10  Wed  Home      W  3.0  0.0
# ...                ...    ...           ...  ...   ...    ...  ...  ...
# Udinese  36 2020-07-19  19:30  Matchweek 34  Sun  Away      L  1.0  2.0
#          37 2020-07-23  19:30  Matchweek 35  Thu  Home      W  2.0  1.0
#          38 2020-07-26  19:30  Matchweek 36  Sun  Away      W  1.0  0.0
#          39 2020-07-29  19:30  Matchweek 37  Wed  Home      L  1.0  2.0
#          40 2020-08-02  20:45  Matchweek 38  Sun  Away      W  1.0  0.0
#
#                   opponent   xg  ...  venue_code  opp_code  day_code  \
# team                             ...
# Atalanta 6      Fiorentina  2.6  ...           0        13         6
#          8        Juventus  1.2  ...           1        18         6
#          9       Sampdoria  2.8  ...           0        32         6
#          11        Bologna  2.3  ...           1         4         6
#          12  Hellas Verona  2.5  ...           1        16         2
# ...                    ...  ...  ...         ...       ...       ...
# Udinese  36         Napoli  0.7  ...           0        24         6
#          37       Juventus  1.0  ...           1        18         3
#          38       Cagliari  0.9  ...           0         6         6
#          39          Lecce  1.0  ...           1        20         2
#          40       Sassuolo  2.1  ...           0        33         6
#
#             gf_rolling ga_rolling sh_rolling sot_rolling  dist_rolling  \
# team
# Atalanta 6         1.8        1.4       13.2         5.6         16.40
#          8         2.0        1.4       12.6         5.2         16.68
#          9         2.2        1.2       11.0         5.2         16.44
#          11        2.0        1.6       13.4         6.8         15.74
#          12        2.0        1.4       15.8         6.4         14.72
# ...                ...        ...        ...         ...           ...
# Udinese  36        1.6        1.0       10.8         3.8         17.32
#          37        1.4        1.4        9.0         3.6         16.82
#          38        1.4        1.2       10.0         3.6         17.52
#          39        1.0        1.2       11.4         4.2         17.66
#          40        1.0        1.0       11.2         4.0         16.58
#
#              pk_rolling  pkatt_rolling
# team
# Atalanta 6          0.4            0.4
#          8          0.4            0.6
#          9          0.4            0.6
#          11         0.4            0.6
#          12         0.2            0.4
# ...                 ...            ...
# Udinese  36         0.0            0.0
#          37         0.0            0.0
#          38         0.0            0.0
#          39         0.0            0.0
#          40         0.0            0.0
#
# [2150 rows x 35 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling.to_csv("Italian Series rolling.csv")

# %%
#Random Forest

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    rf.fit(train[predictors], train["target"])
    predrf = rf.predict(test[predictors])
    combinedrf = pd.DataFrame(dict(actual=test["target"], predicted=predrf), index=test.index)
    RFprecision= precision_score(test["target"], predrf)
    return combinedrf, RFprecision

# %%
combinedrf, RFprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of Random Forest", RFprecision)
# Out:
# Precision of Random Forest 0.504

# %%
print ("Accuracy of Random Forest",accuracy_score(test["target"], predrf))
# Out:
# Accuracy of Random Forest 0.631827731092437

# %%
from sklearn import metrics

# %%
mse = round(metrics.mean_squared_error(test["target"], predrf), 4)
print ("Mean Squared Error of RF",mse)
# Out:
# Mean Squared Error of RF 0.3682

# %%
from sklearn.metrics import classification_report
print('Classification Report of Random Forest: \n',classification_report(test["target"], predrf,digits=4))
# Out:
# Classification Report of Random Forest:
#                precision    recall  f1-score   support
#
#            0     0.6664    0.8207    0.7356      1188
#            1     0.5170    0.3184    0.3941       716
#
#     accuracy                         0.6318      1904
#    macro avg     0.5917    0.5696    0.5648      1904
# weighted avg     0.6102    0.6318    0.6072      1904

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
auc = roc_auc_score(test["target"], predrf)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], predrf)
plt.figure()
plt.plot(fpr, tpr, label='Random Forest (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of Random Forest')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %%
#Support Vector Machine

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    svm.fit(train[predictors], train["target"])
    predsvm = svm.predict(test[predictors])
    combinedsvm = pd.DataFrame(dict(actual=test["target"], predicted=predsvm), index=test.index)
    SVMprecision= precision_score(test["target"], predsvm)
    return combinedsvm, SVMprecision

# %%
combinedsvm, SVMprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of SVM", SVMprecision)
# Out:
# Precision of SVM 0.4726027397260274

# %%
print ("Accuracy of SVM",accuracy_score(test["target"], predsvm))
# Out:
# Accuracy of SVM 0.6239495798319328

# %%
mse = round(metrics.mean_squared_error(test["target"], predsvm), 4)
print ("Mean Squared Error of SVM",mse)
# Out:
# Mean Squared Error of SVM 0.3761

# %%
from sklearn.metrics import classification_report
print('Classification Report of SVM: \n',classification_report(test["target"], predsvm,digits=4))
# Out:
# Classification Report of SVM:
#                precision    recall  f1-score   support
#
#            0     0.6239    1.0000    0.7684      1188
#            1     0.0000    0.0000    0.0000       716
#
#     accuracy                         0.6239      1904
#    macro avg     0.3120    0.5000    0.3842      1904
# weighted avg     0.3893    0.6239    0.4795      1904
# e:\py\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\py\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\py\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
auc1 = roc_auc_score(test["target"], predsvm)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], predsvm)
plt.figure()
plt.plot(fpr, tpr, label='Support Vector Machine (area = %0.2f)' % auc1)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of SVM')
plt.legend(loc="lower right")
plt.savefig('SVM_ROC')
plt.show()

# %%
#Naive Bayes

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    nb.fit(train[predictors], train["target"])
    prednb = nb.predict(test[predictors])
    combinednb = pd.DataFrame(dict(actual=test["target"], predicted=prednb), index=test.index)
    NBprecision= precision_score(test["target"], prednb)
    return combinednb, NBprecision

# %%
combinednb, NBprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of Naive Bayes", NBprecision)
# Out:
# Precision of Naive Bayes 0.5232558139534884

# %%
print ("Accuracy of NB",accuracy_score(test["target"], prednb))
# Out:
# Accuracy of NB 0.6150210084033614

# %%
mse = round(metrics.mean_squared_error(test["target"], prednb), 4)
print ("Mean Squared Error of Naive Bayes",mse)
# Out:
# Mean Squared Error of Naive Bayes 0.385

# %%
from sklearn.metrics import classification_report
print('Classification Report of Naive Bayes: \n',classification_report(test["target"], prednb,digits=4))
# Out:
# Classification Report of Naive Bayes:
#                precision    recall  f1-score   support
#
#            0     0.6298    0.9293    0.7508      1188
#            1     0.4437    0.0936    0.1546       716
#
#     accuracy                         0.6150      1904
#    macro avg     0.5367    0.5114    0.4527      1904
# weighted avg     0.5598    0.6150    0.5266      1904

# %%
auc2 = roc_auc_score(test["target"], prednb)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], prednb)
plt.figure()
plt.plot(fpr, tpr, label='Naive Bayes(area = %0.2f)' % auc2)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of NB')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %%
#Gradient Boosting

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    gb.fit(train[predictors], train["target"])
    predgb = gb.predict(test[predictors])
    combinedgb = pd.DataFrame(dict(actual=test["target"], predicted=predgb), index=test.index)
    GBprecision= precision_score(test["target"], predgb)
    return combinedgb, GBprecision

# %%
combinedgb, GBprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of Gradient Boosting", GBprecision)
# Out:
# Precision of Gradient Boosting 0.5232558139534884

# %%
print ("Accuracy of GB",accuracy_score(test["target"], predgb))
# Out:
# Accuracy of GB 0.6381302521008403

# %%
mse = round(metrics.mean_squared_error(test["target"], predgb), 4)
print ("Mean Squared Error of Gradient Boosting",mse)
# Out:
# Mean Squared Error of Gradient Boosting 0.3619

# %%
from sklearn.metrics import classification_report
print('Classification Report of Gradient Boosting: \n',classification_report(test["target"], predgb,digits=4))
# Out:
# Classification Report of Gradient Boosting:
#                precision    recall  f1-score   support
#
#            0     0.6520    0.9007    0.7565      1188
#            1     0.5513    0.2025    0.2962       716
#
#     accuracy                         0.6381      1904
#    macro avg     0.6017    0.5516    0.5263      1904
# weighted avg     0.6142    0.6381    0.5834      1904

# %%
auc3 = roc_auc_score(test["target"], predgb)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], predgb)
plt.figure()
plt.plot(fpr, tpr, label='Gradient Boosting(area = %0.2f)' % auc3)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of GB')
plt.legend(loc="lower right")
plt.savefig('GB_ROC')
plt.show()

# %%
combinedsvm = combinedsvm.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combinedsvm
# Out:
#       actual  predicted       date      team  opponent result
# 14         1          0 2018-01-06  Atalanta      Roma      W
# 15         0          0 2018-01-21  Atalanta    Napoli      L
# 16         1          0 2018-01-27  Atalanta  Sassuolo      W
# 17         1          0 2018-02-04  Atalanta    Chievo      W
# 18         0          0 2018-02-10  Atalanta   Crotone      D
# ...      ...        ...        ...       ...       ...    ...
# 2145       0          0 2020-07-19   Udinese    Napoli      L
# 2146       1          0 2020-07-23   Udinese  Juventus      W
# 2147       1          0 2020-07-26   Udinese  Cagliari      W
# 2148       0          0 2020-07-29   Udinese     Lecce      L
# 2149       1          0 2020-08-02   Udinese  Sassuolo      W
#
# [1874 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Internazionale": "Inter"} 
mapping = MissingDict(**map_values)

# %%
combinedsvm["new_team"] = combinedsvm["team"].map(mapping)

# %%
merged = combinedsvm.merge(combinedsvm, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       date    team_x opponent_x result_x  \
# 0            1            0 2018-01-06  Atalanta       Roma        W
# 1            0            0 2018-01-21  Atalanta     Napoli        L
# 2            1            0 2018-01-27  Atalanta   Sassuolo        W
# 3            1            0 2018-02-04  Atalanta     Chievo        W
# 4            0            0 2018-02-10  Atalanta    Crotone        D
# ...        ...          ...        ...       ...        ...      ...
# 1839         0            0 2020-07-19   Udinese     Napoli        L
# 1840         1            0 2020-07-23   Udinese   Juventus        W
# 1841         1            0 2020-07-26   Udinese   Cagliari        W
# 1842         0            0 2020-07-29   Udinese      Lecce        L
# 1843         1            0 2020-08-02   Udinese   Sassuolo        W
#
#      new_team_x  actual_y  predicted_y    team_y opponent_y result_y  \
# 0      Atalanta         0            0      Roma   Atalanta        L
# 1      Atalanta         1            0    Napoli   Atalanta        W
# 2      Atalanta         0            0  Sassuolo   Atalanta        L
# 3      Atalanta         0            0    Chievo   Atalanta        L
# 4      Atalanta         0            1   Crotone   Atalanta        D
# ...         ...       ...          ...       ...        ...      ...
# 1839    Udinese         1            0    Napoli    Udinese        W
# 1840    Udinese         0            0  Juventus    Udinese        L
# 1841    Udinese         0            0  Cagliari    Udinese        L
# 1842    Udinese         1            0     Lecce    Udinese        W
# 1843    Udinese         0            0  Sassuolo    Udinese        L
#
#      new_team_y
# 0          Roma
# 1        Napoli
# 2      Sassuolo
# 3        Chievo
# 4       Crotone
# ...         ...
# 1839     Napoli
# 1840   Juventus
# 1841   Cagliari
# 1842      Lecce
# 1843   Sassuolo
#
# [1844 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    100
# 0     89
# Name: actual_x, dtype: int64

# %%
100+89
# Out:
# 189

# %%
100/189
# Out:
# 0.5291005291005291
