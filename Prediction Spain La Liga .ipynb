# %%
import pandas as pd

# %%
matches = pd.read_csv("NewLa Liga Spain.csv", index_col=0)

# %%
df4 = pd.DataFrame(matches)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 1  2022-08-14  22:00  La Liga  Matchweek 1  Sun  Away      W  2.0  1.0
# 2  2022-08-20  22:00  La Liga  Matchweek 2  Sat  Away      W  4.0  1.0
# 3  2022-08-28  22:00  La Liga  Matchweek 3  Sun  Away      W  3.0  1.0
# 0  2022-08-15  21:30  La Liga  Matchweek 1  Mon  Home      W  3.0  0.0
# 1  2022-08-20  19:30  La Liga  Matchweek 2  Sat  Away      W  2.0  1.0
#
#      opponent  ...           referee  match report  notes    sh   sot  dist  \
# 1     Almería  ...     Juan Martínez  Match Report    NaN  29.0  15.0  17.9
# 2  Celta Vigo  ...         Jesús Gil  Match Report    NaN  15.0   6.0  18.7
# 3    Espanyol  ...      Mario Melero  Match Report    NaN  19.0   6.0  15.6
# 0       Elche  ...  Guillermo Cuadra  Match Report    NaN  17.0   8.0  15.4
# 1    Mallorca  ...    Pablo González  Match Report    NaN   6.0   1.0  17.2
#
#     pk pkatt  season         team
# 1  0.0   0.0    2022  Real Madrid
# 2  1.0   2.0    2022  Real Madrid
# 3  0.0   0.0    2022  Real Madrid
# 0  0.0   0.0    2022   Real Betis
# 1  2.0   2.0    2022   Real Betis
#
# [5 rows x 26 columns]

# %%
matches.shape
# Out:
# (12716, 26)

# %%
matches["team"].value_counts()
# Out:
# Real Madrid            649
# Barcelona              649
# Valencia               649
# Sevilla                649
# Atletico Madrid        649
# Athletic Club          649
# Espanyol               611
# Villarreal             611
# Getafe                 573
# Real Betis             535
# Real Sociedad          535
# Osasuna                497
# Celta Vigo             460
# Levante                456
# Malaga                 418
# Deportivo La Coruna    418
# Mallorca               383
# Granada                342
# Valladolid             269
# Rayo Vallecano         269
# Racing Santander       266
# Zaragoza               266
# Almeria                231
# Eibar                  228
# Alaves                 228
# Sporting Gijon         228
# Leganes                152
# Cadiz                  118
# Elche                  117
# Recreativo             114
# Las Palmas             114
# Girona                  79
# Huesca                  38
# Tenerife                38
# Cordoba                 38
# Hercules                38
# Xerez                   38
# Numancia                38
# Gimnastic               38
# Real Murcia             38
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 2     353
# Matchweek 3     353
# Matchweek 1     353
# Matchweek 4     335
# Matchweek 5     333
# Matchweek 27    333
# Matchweek 14    333
# Matchweek 28    333
# Matchweek 10    333
# Matchweek 12    333
# Matchweek 23    333
# Matchweek 25    333
# Matchweek 24    333
# Matchweek 29    333
# Matchweek 21    333
# Matchweek 35    333
# Matchweek 9     333
# Matchweek 26    333
# Matchweek 36    333
# Matchweek 33    333
# Matchweek 37    333
# Matchweek 22    333
# Matchweek 15    333
# Matchweek 11    333
# Matchweek 31    333
# Matchweek 17    333
# Matchweek 20    333
# Matchweek 38    333
# Matchweek 16    333
# Matchweek 19    333
# Matchweek 7     333
# Matchweek 8     333
# Matchweek 34    333
# Matchweek 6     333
# Matchweek 18    333
# Matchweek 30    333
# Matchweek 32    333
# Matchweek 13    333
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga     opponent  \
# 1  2022-08-14  22:00   Matchweek 1  Sun  Away      W  2.0  1.0      Almería
# 2  2022-08-20  22:00   Matchweek 2  Sat  Away      W  4.0  1.0   Celta Vigo
# 3  2022-08-28  22:00   Matchweek 3  Sun  Away      W  3.0  1.0     Espanyol
# 0  2022-08-15  21:30   Matchweek 1  Mon  Home      W  3.0  0.0        Elche
# 1  2022-08-20  19:30   Matchweek 2  Sat  Away      W  2.0  1.0     Mallorca
# ..        ...    ...           ...  ...   ...    ...  ...  ...          ...
# 33 2006-04-23    NaN  Matchweek 34  Sun  Away      L  1.0  2.0  Real Madrid
# 34 2006-04-30    NaN  Matchweek 35  Sun  Home      L  2.0  3.0  Racing Sant
# 35 2006-05-03    NaN  Matchweek 36  Wed  Away      L  1.0  2.0   Villarreal
# 36 2006-05-06    NaN  Matchweek 37  Sat  Home      L  0.0  2.0      Sevilla
# 37 2006-05-13    NaN  Matchweek 38  Sat  Away      L  0.0  5.0        Cádiz
#
#      xg  ...             referee  match report    sh   sot  dist   pk pkatt  \
# 1   2.4  ...       Juan Martínez  Match Report  29.0  15.0  17.9  0.0   0.0
# 2   3.4  ...           Jesús Gil  Match Report  15.0   6.0  18.7  1.0   2.0
# 3   1.6  ...        Mario Melero  Match Report  19.0   6.0  15.6  0.0   0.0
# 0   3.0  ...    Guillermo Cuadra  Match Report  17.0   8.0  15.4  0.0   0.0
# 1   2.2  ...      Pablo González  Match Report   6.0   1.0  17.2  2.0   2.0
# ..  ...  ...                 ...           ...   ...   ...   ...  ...   ...
# 33  NaN  ...  Iturralde González  Match Report   NaN   NaN   NaN  0.0   NaN
# 34  NaN  ...          Ayza Gámez  Match Report   NaN   NaN   NaN  0.0   NaN
# 35  NaN  ...     Mejuto González  Match Report   NaN   NaN   NaN  1.0   NaN
# 36  NaN  ...          Pérez Lima  Match Report   NaN   NaN   NaN  0.0   NaN
# 37  NaN  ...    Velasco Carballo  Match Report   NaN   NaN   NaN  0.0   NaN
#
#     season         team  target
# 1     2022  Real Madrid       1
# 2     2022  Real Madrid       1
# 3     2022  Real Madrid       1
# 0     2022   Real Betis       1
# 1     2022   Real Betis       1
# ..     ...          ...     ...
# 33    2008       Malaga       0
# 34    2008       Malaga       0
# 35    2008       Malaga       0
# 36    2008       Malaga       0
# 37    2008       Malaga       0
#
# [12716 rows x 25 columns]

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga     opponent  \
# 1  2022-08-14  22:00   Matchweek 1  Sun  Away      W  2.0  1.0      Almería
# 2  2022-08-20  22:00   Matchweek 2  Sat  Away      W  4.0  1.0   Celta Vigo
# 3  2022-08-28  22:00   Matchweek 3  Sun  Away      W  3.0  1.0     Espanyol
# 0  2022-08-15  21:30   Matchweek 1  Mon  Home      W  3.0  0.0        Elche
# 1  2022-08-20  19:30   Matchweek 2  Sat  Away      W  2.0  1.0     Mallorca
# ..        ...    ...           ...  ...   ...    ...  ...  ...          ...
# 33 2006-04-23    NaN  Matchweek 34  Sun  Away      L  1.0  2.0  Real Madrid
# 34 2006-04-30    NaN  Matchweek 35  Sun  Home      L  2.0  3.0  Racing Sant
# 35 2006-05-03    NaN  Matchweek 36  Wed  Away      L  1.0  2.0   Villarreal
# 36 2006-05-06    NaN  Matchweek 37  Sat  Home      L  0.0  2.0      Sevilla
# 37 2006-05-13    NaN  Matchweek 38  Sat  Away      L  0.0  5.0        Cádiz
#
#      xg  ...   sot  dist   pk pkatt season         team target  venue_code  \
# 1   2.4  ...  15.0  17.9  0.0   0.0   2022  Real Madrid      1           0
# 2   3.4  ...   6.0  18.7  1.0   2.0   2022  Real Madrid      1           0
# 3   1.6  ...   6.0  15.6  0.0   0.0   2022  Real Madrid      1           0
# 0   3.0  ...   8.0  15.4  0.0   0.0   2022   Real Betis      1           1
# 1   2.2  ...   1.0  17.2  2.0   2.0   2022   Real Betis      1           0
# ..  ...  ...   ...   ...  ...   ...    ...          ...    ...         ...
# 33  NaN  ...   NaN   NaN  0.0   NaN   2008       Malaga      0           0
# 34  NaN  ...   NaN   NaN  0.0   NaN   2008       Malaga      0           1
# 35  NaN  ...   NaN   NaN  1.0   NaN   2008       Malaga      0           0
# 36  NaN  ...   NaN   NaN  0.0   NaN   2008       Malaga      0           1
# 37  NaN  ...   NaN   NaN  0.0   NaN   2008       Malaga      0           0
#
#     opp_code  day_code
# 1          1         6
# 2          6         5
# 3         11         6
# 0         10         0
# 1         22         5
# ..       ...       ...
# 33        28         6
# 34        26         6
# 35        37         2
# 36        32         5
# 37         7         5
#
# [12716 rows x 28 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
svm = svm.SVC(kernel='linear')

# %%
nb = GaussianNB()

# %%
gb = GradientBoostingClassifier(learning_rate=0.05,max_depth=3,max_features=0.5,random_state=0)

# %%
train = matches[matches["date"] < '2018-01-01']

# %%
test = matches[matches["date"] > '2018-01-01']

# %%
predictors = ["venue_code", "opp_code", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
svm.fit(train[predictors], train["target"])
# Out:
# SVC(kernel='linear')

# %%
nb.fit(train[predictors], train["target"])
# Out:
# GaussianNB()

# %%
gb.fit(train[predictors], train["target"])
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_features=0.5, random_state=0)

# %%
predrf = rf.predict(test[predictors])
predsvm= svm.predict(test[predictors])
prednb= nb.predict(test[predictors])
predgb=gb.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
RFacc = accuracy_score(test["target"], predrf)
SVMacc = accuracy_score(test["target"], predsvm)
NBacc = accuracy_score(test["target"], prednb)
GBacc = accuracy_score(test["target"], predgb)

# %%
combinedrf = pd.DataFrame(dict(actual=test["target"], predicted=predrf))
combinedsvm = pd.DataFrame(dict(actual=test["target"], predicted=predsvm))
combinednb = pd.DataFrame(dict(actual=test["target"], predicted=prednb))
combinedgb= pd.DataFrame(dict(actual=test["target"], predicted=predgb))

# %%
pd.crosstab(index=combinedrf["actual"], columns=combinedrf["predicted"])
# Out:
# predicted     0    1
# actual
# 0          1540  498
# 1           760  460

# %%
pd.crosstab(index=combinedsvm["actual"], columns=combinedsvm["predicted"])
# Out:
# predicted     0
# actual
# 0          2038
# 1          1220

# %%
pd.crosstab(index=combinednb["actual"], columns=combinednb["predicted"])
# Out:
# predicted     0    1
# actual
# 0          1909  129
# 1          1125   95

# %%
pd.crosstab(index=combinedgb["actual"], columns=combinedgb["predicted"])
# Out:
# predicted     0    1
# actual
# 0          1630  408
# 1           755  465

# %%
from sklearn.metrics import precision_score

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Real Madrid").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(5, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 6  2015-09-26  18:15   Matchweek 6  Sat  Home      D  0.0  0.0
# 8  2015-10-04  20:30   Matchweek 7  Sun  Away      D  1.0  1.0
# 9  2015-10-17  16:00   Matchweek 8  Sat  Home      W  3.0  0.0
# 11 2015-10-24  16:00   Matchweek 9  Sat  Away      W  3.0  1.0
# 12 2015-10-31  16:00  Matchweek 10  Sat  Home      W  3.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 53 2022-05-15  19:30  Matchweek 37  Sun  Away      D  1.0  1.0
# 54 2022-05-20  21:00  Matchweek 38  Fri  Home      D  0.0  0.0
# 1  2022-08-14  22:00   Matchweek 1  Sun  Away      W  2.0  1.0
# 2  2022-08-20  22:00   Matchweek 2  Sat  Away      W  4.0  1.0
# 3  2022-08-28  22:00   Matchweek 3  Sun  Away      W  3.0  1.0
#
#            opponent   xg  ...  venue_code  opp_code  day_code gf_rolling  \
# 6            Málaga  3.2  ...           1        23         5        2.8
# 8   Atlético Madrid  0.5  ...           0         3         6        2.8
# 9           Levante  1.5  ...           1        21         5        2.0
# 11       Celta Vigo  2.5  ...           0         6         5        1.4
# 12       Las Palmas  2.4  ...           1        19         5        1.8
# ..              ...  ...  ...         ...       ...       ...        ...
# 53            Cádiz  2.0  ...           0         7         6        3.2
# 54            Betis  1.3  ...           1         5         4        2.8
# 1           Almería  2.4  ...           0         1         6        2.2
# 2        Celta Vigo  3.4  ...           0         6         5        1.8
# 3          Espanyol  1.6  ...           0        11         6        2.6
#
#    ga_rolling sh_rolling sot_rolling  dist_rolling  pk_rolling  pkatt_rolling
# 6         0.2       21.0         8.6         17.74         0.2            0.2
# 8         0.2       21.8         8.8         16.50         0.2            0.2
# 9         0.4       19.4         7.0         17.22         0.2            0.2
# 11        0.4       20.4         6.6         17.54         0.0            0.0
# 12        0.6       19.2         6.2         17.42         0.0            0.0
# ..        ...        ...         ...           ...         ...            ...
# 53        0.8       18.4         8.0         18.50         0.0            0.4
# 54        0.6       18.4         8.2         17.92         0.0            0.4
# 1         0.4       17.6         7.4         18.34         0.0            0.0
# 2         0.6       21.0         9.4         18.98         0.0            0.0
# 3         0.6       21.0         9.4         18.22         0.2            0.4
#
# [222 rows x 35 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                     date   time         round  day venue result   gf   ga  \
# team
# Alaves     5  2017-09-23  16:15   Matchweek 6  Sat  Home      L  1.0  2.0
#            6  2017-09-30  18:30   Matchweek 7  Sat  Away      W  2.0  0.0
#            7  2017-10-14  18:30   Matchweek 8  Sat  Home      L  0.0  2.0
#            8  2017-10-21  16:15   Matchweek 9  Sat  Away      L  0.0  2.0
#            10 2017-10-28  13:00  Matchweek 10  Sat  Home      L  1.0  2.0
# ...                  ...    ...           ...  ...   ...    ...  ...  ...
# Villarreal 52 2022-05-15  19:30  Matchweek 37  Sun  Home      L  1.0  2.0
#            53 2022-05-22  22:00  Matchweek 38  Sun  Away      W  2.0  0.0
#            0  2022-08-13  19:00   Matchweek 1  Sat  Away      W  3.0  0.0
#            2  2022-08-21  19:30   Matchweek 2  Sun  Away      W  2.0  0.0
#            4  2022-08-28  17:30   Matchweek 3  Sun  Away      D  0.0  0.0
#
#                       opponent   xg  ...  venue_code  opp_code  day_code  \
# team                                 ...
# Alaves     5       Real Madrid  0.7  ...           1        28         5
#            6           Levante  2.3  ...           0        21         5
#            7     Real Sociedad  0.5  ...           1        30         5
#            8             Betis  0.7  ...           0         5         5
#            10         Valencia  0.8  ...           1        35         5
# ...                        ...  ...  ...         ...       ...       ...
# Villarreal 52    Real Sociedad  0.7  ...           1        30         6
#            53        Barcelona  0.7  ...           0         4         6
#            0        Valladolid  1.4  ...           0        36         5
#            2   Atlético Madrid  2.0  ...           0         3         6
#            4            Getafe  0.8  ...           0        12         6
#
#               gf_rolling ga_rolling sh_rolling sot_rolling  dist_rolling  \
# team
# Alaves     5         0.0        1.6        9.6         2.6         20.22
#            6         0.2        1.8        9.6         2.6         19.58
#            7         0.6        1.4        9.0         2.8         17.86
#            8         0.6        1.6        9.6         2.2         18.88
#            10        0.6        1.4        7.8         2.4         17.82
# ...                  ...        ...        ...         ...           ...
# Villarreal 52        2.2        1.0       12.8         6.0         14.94
#            53        2.0        1.2       12.8         5.6         15.20
#            0         2.0        1.2       11.4         5.4         14.28
#            2         2.4        0.8       10.0         5.0         14.14
#            4         2.6        0.6       11.2         4.6         14.84
#
#                pk_rolling  pkatt_rolling
# team
# Alaves     5          0.0            0.2
#            6          0.0            0.0
#            7          0.0            0.0
#            8          0.0            0.0
#            10         0.0            0.0
# ...                   ...            ...
# Villarreal 52         0.2            0.2
#            53         0.2            0.2
#            0          0.0            0.0
#            2          0.0            0.0
#            4          0.0            0.0
#
# [4095 rows x 35 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 5  2017-09-23  16:15   Matchweek 6  Sat  Home      L  1.0  2.0
# 6  2017-09-30  18:30   Matchweek 7  Sat  Away      W  2.0  0.0
# 7  2017-10-14  18:30   Matchweek 8  Sat  Home      L  0.0  2.0
# 8  2017-10-21  16:15   Matchweek 9  Sat  Away      L  0.0  2.0
# 10 2017-10-28  13:00  Matchweek 10  Sat  Home      L  1.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 52 2022-05-15  19:30  Matchweek 37  Sun  Home      L  1.0  2.0
# 53 2022-05-22  22:00  Matchweek 38  Sun  Away      W  2.0  0.0
# 0  2022-08-13  19:00   Matchweek 1  Sat  Away      W  3.0  0.0
# 2  2022-08-21  19:30   Matchweek 2  Sun  Away      W  2.0  0.0
# 4  2022-08-28  17:30   Matchweek 3  Sun  Away      D  0.0  0.0
#
#            opponent   xg  ...  venue_code  opp_code  day_code gf_rolling  \
# 5       Real Madrid  0.7  ...           1        28         5        0.0
# 6           Levante  2.3  ...           0        21         5        0.2
# 7     Real Sociedad  0.5  ...           1        30         5        0.6
# 8             Betis  0.7  ...           0         5         5        0.6
# 10         Valencia  0.8  ...           1        35         5        0.6
# ..              ...  ...  ...         ...       ...       ...        ...
# 52    Real Sociedad  0.7  ...           1        30         6        2.2
# 53        Barcelona  0.7  ...           0         4         6        2.0
# 0        Valladolid  1.4  ...           0        36         5        2.0
# 2   Atlético Madrid  2.0  ...           0         3         6        2.4
# 4            Getafe  0.8  ...           0        12         6        2.6
#
#    ga_rolling sh_rolling sot_rolling  dist_rolling  pk_rolling  pkatt_rolling
# 5         1.6        9.6         2.6         20.22         0.0            0.2
# 6         1.8        9.6         2.6         19.58         0.0            0.0
# 7         1.4        9.0         2.8         17.86         0.0            0.0
# 8         1.6        9.6         2.2         18.88         0.0            0.0
# 10        1.4        7.8         2.4         17.82         0.0            0.0
# ..        ...        ...         ...           ...         ...            ...
# 52        1.0       12.8         6.0         14.94         0.2            0.2
# 53        1.2       12.8         5.6         15.20         0.2            0.2
# 0         1.2       11.4         5.4         14.28         0.0            0.0
# 2         0.8       10.0         5.0         14.14         0.0            0.0
# 4         0.6       11.2         4.6         14.84         0.0            0.0
#
# [4095 rows x 35 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling.to_csv("Spain la liga rolling.csv")

# %%
#Random Forest

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    rf.fit(train[predictors], train["target"])
    predrf = rf.predict(test[predictors])
    combinedrf = pd.DataFrame(dict(actual=test["target"], predicted=predrf), index=test.index)
    RFprecision= precision_score(test["target"], predrf)
    return combinedrf, RFprecision

# %%
combinedrf, RFprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of Random Forest", RFprecision)
# Out:
# Precision of Random Forest 0.5418326693227091

# %%
print ("Accuracy of Random Forest",accuracy_score(test["target"], predrf))
# Out:
# Accuracy of Random Forest 0.6138735420503376

# %%
from sklearn import metrics

# %%
mse = round(metrics.mean_squared_error(test["target"], predrf), 4)
print ("Mean Squared Error of RF",mse)
# Out:
# Mean Squared Error of RF 0.3861

# %%
from sklearn.metrics import classification_report
print('Classification Report of Random Forest: \n',classification_report(test["target"], predrf,digits=4))
# Out:
# Classification Report of Random Forest:
#                precision    recall  f1-score   support
#
#            0     0.6696    0.7556    0.7100      2038
#            1     0.4802    0.3770    0.4224      1220
#
#     accuracy                         0.6139      3258
#    macro avg     0.5749    0.5663    0.5662      3258
# weighted avg     0.5986    0.6139    0.6023      3258

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
auc = roc_auc_score(test["target"], predrf)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], predrf)
plt.figure()
plt.plot(fpr, tpr, label='Random Forest (area = %0.2f)' % auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of Random Forest')
plt.legend(loc="lower right")
plt.savefig('RF_ROC')
plt.show()

# %%
#Support Vector Machine

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    svm.fit(train[predictors], train["target"])
    predsvm = svm.predict(test[predictors])
    combinedsvm = pd.DataFrame(dict(actual=test["target"], predicted=predsvm), index=test.index)
    SVMprecision= precision_score(test["target"], predsvm)
    return combinedsvm, SVMprecision

# %%
combinedsvm, SVMprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of SVM", SVMprecision)
# Out:
# Precision of SVM 0.5626477541371159

# %%
print ("Accuracy of SVM",accuracy_score(test["target"], predsvm))
# Out:
# Accuracy of SVM 0.625537139349294

# %%
mse = round(metrics.mean_squared_error(test["target"], predsvm), 4)
print ("Mean Squared Error of SVM",mse)
# Out:
# Mean Squared Error of SVM 0.3745

# %%
from sklearn.metrics import classification_report
print('Classification Report of SVM: \n',classification_report(test["target"], predsvm,digits=4))
# Out:
# Classification Report of SVM:
#                precision    recall  f1-score   support
#
#            0     0.6255    1.0000    0.7696      2038
#            1     0.0000    0.0000    0.0000      1220
#
#     accuracy                         0.6255      3258
#    macro avg     0.3128    0.5000    0.3848      3258
# weighted avg     0.3913    0.6255    0.4814      3258
# e:\py\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\py\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# e:\py\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
auc1 = roc_auc_score(test["target"], predsvm)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], predsvm)
plt.figure()
plt.plot(fpr, tpr, label='Support Vector Machine (area = %0.2f)' % auc1)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of SVM')
plt.legend(loc="lower right")
plt.savefig('SVM_ROC')
plt.show()

# %%
#Naive Bayes

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    nb.fit(train[predictors], train["target"])
    prednb = nb.predict(test[predictors])
    combinednb = pd.DataFrame(dict(actual=test["target"], predicted=prednb), index=test.index)
    NBprecision= precision_score(test["target"], prednb)
    return combinednb, NBprecision

# %%
combinednb, NBprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of Naive Bayes", NBprecision)
# Out:
# Precision of Naive Bayes 0.48748159057437407

# %%
print ("Accuracy of NB",accuracy_score(test["target"], prednb))
# Out:
# Accuracy of NB 0.6151012891344383

# %%
mse = round(metrics.mean_squared_error(test["target"], prednb), 4)
print ("Mean Squared Error of Naive Bayes",mse)
# Out:
# Mean Squared Error of Naive Bayes 0.3849

# %%
from sklearn.metrics import classification_report
print('Classification Report of Naive Bayes: \n',classification_report(test["target"], prednb,digits=4))
# Out:
# Classification Report of Naive Bayes:
#                precision    recall  f1-score   support
#
#            0     0.6292    0.9367    0.7528      2038
#            1     0.4241    0.0779    0.1316      1220
#
#     accuracy                         0.6151      3258
#    macro avg     0.5267    0.5073    0.4422      3258
# weighted avg     0.5524    0.6151    0.5202      3258

# %%
auc2 = roc_auc_score(test["target"], prednb)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], prednb)
plt.figure()
plt.plot(fpr, tpr, label='Naive Bayes(area = %0.2f)' % auc2)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of NB')
plt.legend(loc="lower right")
plt.savefig('NB_ROC')
plt.show()

# %%
#Gradient Boosting

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2018-01-01']
    test = data[data["date"] > '2018-01-01']
    gb.fit(train[predictors], train["target"])
    predgb = gb.predict(test[predictors])
    combinedgb = pd.DataFrame(dict(actual=test["target"], predicted=predgb), index=test.index)
    GBprecision= precision_score(test["target"], predgb)
    return combinedgb, GBprecision

# %%
combinedgb, GBprecision = make_predictions(matches_rolling, predictors + new_cols)

# %%
print ("Precision of Gradient Boosting", GBprecision)
# Out:
# Precision of Gradient Boosting 0.5698166431593794

# %%
print ("Accuracy of GB",accuracy_score(test["target"], predgb))
# Out:
# Accuracy of GB 0.6430325352977286

# %%
mse = round(metrics.mean_squared_error(test["target"], predgb), 4)
print ("Mean Squared Error of Gradient Boosting",mse)
# Out:
# Mean Squared Error of Gradient Boosting 0.357

# %%
from sklearn.metrics import classification_report
print('Classification Report of Gradient Boosting: \n',classification_report(test["target"], predgb,digits=4))
# Out:
# Classification Report of Gradient Boosting:
#                precision    recall  f1-score   support
#
#            0     0.6834    0.7998    0.7371      2038
#            1     0.5326    0.3811    0.4443      1220
#
#     accuracy                         0.6430      3258
#    macro avg     0.6080    0.5905    0.5907      3258
# weighted avg     0.6270    0.6430    0.6274      3258

# %%
auc3 = roc_auc_score(test["target"], predgb)

# %%
fpr, tpr, thresholds = roc_curve(test["target"], predgb)
plt.figure()
plt.plot(fpr, tpr, label='Gradient Boosting(area = %0.2f)' % auc3)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of GB')
plt.legend(loc="lower right")
plt.savefig('GB_ROC')
plt.show()

# %%
combinednb = combinednb.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combinednb
# Out:
#       actual  predicted       date        team         opponent result
# 12         0          0 2018-01-07      Alaves    Athletic Club      L
# 13         1          0 2018-01-14      Alaves          Sevilla      W
# 14         0          0 2018-01-21      Alaves          Leganés      D
# 15         0          0 2018-01-28      Alaves        Barcelona      L
# 16         1          0 2018-02-03      Alaves       Celta Vigo      W
# ...      ...        ...        ...         ...              ...    ...
# 4090       0          1 2022-05-15  Villarreal    Real Sociedad      L
# 4091       1          0 2022-05-22  Villarreal        Barcelona      W
# 4092       1          0 2022-08-13  Villarreal       Valladolid      W
# 4093       1          0 2022-08-21  Villarreal  Atlético Madrid      W
# 4094       0          0 2022-08-28  Villarreal           Getafe      D
#
# [3215 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values= {"AtlÃ©tico Madrid": "Atletico Madrid", "AlmerÃ­a": "Almeria", "CÃ¡diz": "Cadiz", "AlavÃ©s": "Alaves", "Real Betis": "Betis", "LeganÃ©s": "Leganes","La CoruÃ±a":"Deportivo La Coruna"}
mapping = MissingDict(**map_values)

# %%
combinednb["new_team"] = combinednb["team"].map(mapping)

# %%
merged = combinednb.merge(combinednb, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       date         team_x       opponent_x  \
# 0            1            1 2018-01-07  Athletic Club           Alavés
# 1            0            1 2018-01-14  Athletic Club         Espanyol
# 2            0            1 2018-01-19  Athletic Club           Getafe
# 3            0            1 2018-01-26  Athletic Club            Eibar
# 4            0            1 2018-02-04  Athletic Club           Girona
# ...        ...          ...        ...            ...              ...
# 2492         0            1 2022-05-15     Villarreal    Real Sociedad
# 2493         1            0 2022-05-22     Villarreal        Barcelona
# 2494         1            0 2022-08-13     Villarreal       Valladolid
# 2495         1            0 2022-08-21     Villarreal  Atlético Madrid
# 2496         0            0 2022-08-28     Villarreal           Getafe
#
#      result_x     new_team_x  actual_y  predicted_y           team_y  \
# 0           W  Athletic Club         0            0           Alaves
# 1           D  Athletic Club         0            0         Espanyol
# 2           D  Athletic Club         0            0           Getafe
# 3           D  Athletic Club         0            0            Eibar
# 4           L  Athletic Club         1            0           Girona
# ...       ...            ...       ...          ...              ...
# 2492        L     Villarreal         1            0    Real Sociedad
# 2493        W     Villarreal         0            0        Barcelona
# 2494        W     Villarreal         0            0       Valladolid
# 2495        W     Villarreal         0            0  Atletico Madrid
# 2496        D     Villarreal         0            0           Getafe
#
#          opponent_y result_y       new_team_y
# 0     Athletic Club        L           Alaves
# 1     Athletic Club        D         Espanyol
# 2     Athletic Club        D           Getafe
# 3     Athletic Club        D            Eibar
# 4     Athletic Club        W           Girona
# ...             ...      ...              ...
# 2492     Villarreal        W    Real Sociedad
# 2493     Villarreal        L        Barcelona
# 2494     Villarreal        L       Valladolid
# 2495     Villarreal        L  Atletico Madrid
# 2496     Villarreal        D           Getafe
#
# [2497 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 0    217
# 1    216
# Name: actual_x, dtype: int64

# %%
217+216
# Out:
# 433

# %%
217/433
# Out:
# 0.5011547344110855
